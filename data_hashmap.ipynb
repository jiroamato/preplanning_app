# %%
import fillpdf
from fillpdf import fillpdfs
from datetime import datetime, date

# %%
print(date.today().strftime("%B %d, %Y"))
# Out:
# October 16, 2024

# %% [markdown]
# This is for the first PDF Forms\Protector Plus TruStage Application form.pdf

# %%
fillpdfs.get_form_fields("Filled Forms\Jiro_Amato - Protector Plus TruStage Application form.pdf", sort=False, page_number=None)
# Out:
# {'undefined': '',
#  'undefined_2': '',
#  'I understand that this is an enrollment into a group policy in order to provide funding for funeral expenses': 'On',
#  'Contract': '',
#  'Establishment Name': 'Kearney Columbia-Bowell Chapel',
#  'Phone': '604-521-4881',
#  'Email': 'Columbia-Bowell@KearneyFS.com',
#  'Address': '219-6th Street',
#  'City': 'New Westminster',
#  'Province': 'BC',
#  'Postal Code': 'V3L 3A3',
#  'First Name': 'Jiro',
#  'MI': '',
#  'Last Name': 'Amato',
#  'Birthdate ddmmyy': '',
#  'Age': '',
#  'Gender': '',
#  'SIN': '',
#  'Occupation': '',
#  'Phone_2': '',
#  'Email_2': '',
#  'Mailing Address': '',
#  'City_2': '',
#  'Province_2': '',
#  'Postal Code_2': '',
#  'Physical Address': '',
#  'City_3': '',
#  'Province_3': '',
#  'Postal Code_3': '',
#  'Name': '',
#  'Relationship': '',
#  'Phone_3': '',
#  'Email_3': '',
#  'Address \\(if different\\)': '',
#  'City_4': '',
#  'Province_4': '',
#  'Postal Code_4': '',
#  '3A Goods and Services': '',
# ...

# %%
fillpdfs.get_form_fields("Forms\Protector Plus TruStage Application form.pdf", sort=False, page_number=None)
# Out:
# {'undefined': '',
#  'undefined_2': '',
#  'I understand that this is an enrollment into a group policy in order to provide funding for funeral expenses': '',
#  'Contract': '',
#  'Establishment Name': '',
#  'Phone': '',
#  'Email': None,
#  'Address': '',
#  'City': '',
#  'Province': '',
#  'First Name': '',
#  'MI': '',
#  'Last Name': '',
#  'Birthdate ddmmyy': '',
#  'Age': '',
#  'Gender': '',
#  'SIN': '',
#  'Occupation': '',
#  'Phone_2': '',
#  'Email_2': None,
#  'Mailing Address': '',
#  'City_2': '',
#  'Province_2': '',
#  'Postal Code_2': '',
#  'Physical Address': '',
#  'City_3': '',
#  'Province_3': '',
#  'Postal Code_3': '',
#  'Name': '',
#  'Relationship': '',
#  'Phone_3': '',
#  'Email_3': None,
#  'Address \\(if different\\)': '',
#  'City_4': '',
#  'Province_4': '',
#  '3A Goods and Services': None,
#  '3B MonumentMarker': None,
#  '3C Other Expenses': None,
#  '3D Final Documents Service': None,
#  '3E Journey Home': '',
#  'Total 3': '',
# ...

# %% [markdown]
# This is for the second PDF Forms\Personal Information Sheet Auto Fill.pdf

# %%
fillpdfs.get_form_fields("Forms\Personal Information Sheet.pdf", sort=False, page_number=None)
# Out:
# {'Last name': '',
#  'First name': '',
#  'Middle name': '',
#  'Name at Birth if different': '',
#  'Address': '',
#  'Postal Code': '',
#  'Phone': '',
#  'Birthplace': '',
#  'Date of Birth': '',
#  'Occupation': '',
#  'Industry': '',
#  'Years': '',
#  'Marital Status': '',
#  'SIN': '',
#  'Health Card': '',
#  'Husbands Name or Maiden Name of Wife': '',
#  'Last name of Father': '',
#  'First': '',
#  'Middle': '',
#  'Fathers Place of Birth': '',
#  'Maiden name of Mother': '',
#  'First_2': '',
#  'Middle_2': '',
#  'Mothers Place of Birth': '',
#  'Physicians Name': '',
#  'Death Certificate #': '',
#  'Last name_2': '',
#  'First name_2': '',
#  'Middle name_2': '',
#  'Relationship': '',
#  'Phone_2': '',
#  'Address_2': '',
#  'Postal Code_2': '',
#  'Email': '',
#  'Kearney ColumbiaBowell Chapel': '',
#  'Kearney Vancouver Chapel': '',
#  'Kearney Cloverdale South Surrey': '',
#  'Kearney Burnaby Chapel': '',
#  'Check Box2': '',
#  'Check Box3': 'Yes'}

# %%
fillpdfs.get_form_fields("Filled_Forms\Kris_Garcia - Personal Information Sheet.pdf", sort=False, page_number=None)
# Out:
# {'Last name': 'Garcia',
#  'First name': 'Kris',
#  'Middle name': '',
#  'Name at Birth if different': '',
#  'Address': '3 - 5410 Dundee St., Vancouver, BC',
#  'Postal Code': 'V5R 5Y6',
#  'Phone': '778-926-8845',
#  'Birthplace': '',
#  'Date of Birth': 'May 5, 1984',
#  'Occupation': 'Supervisor',
#  'Industry': '',
#  'Years': '',
#  'Marital Status': '',
#  'SIN': '999-999-999',
#  'Health Card': '',
#  'Husbands Name or Maiden Name of Wife': '',
#  'Last name of Father': '',
#  'First': '',
#  'Middle': '',
#  'Fathers Place of Birth': '',
#  'Maiden name of Mother': '',
#  'First_2': '',
#  'Middle_2': '',
#  'Mothers Place of Birth': '',
#  'Physicians Name': '',
#  'Death Certificate #': '',
#  'Last name_2': '',
#  'First name_2': '',
#  'Middle name_2': '',
#  'Relationship': '',
#  'Phone_2': '',
#  'Address_2': '',
#  'Postal Code_2': '',
#  'Email': '',
#  'Check Box1': 'Yes',
#  'Check Box 2': 'Yes',
#  'Check Box 3': 'Yes',
#  'Check Box 4': 'Yes',
# ...

# %% [markdown]
# Third PDF at Forms\Instructions Concerning My Arrangements.pdf

# %%
fillpdfs.get_form_fields("Forms\Instructions Concerning My Arrangements.pdf", sort=False, page_number=None)
# Out:
# {'Date': '',
#  'Kearney ColumbiaBowell Chapel': '',
#  'Kearney Vancouver Chapel': '',
#  'Kearney Cloverdale South Surrey': 'Off',
#  'Kearney Burnaby Chapel': '',
#  'Name': '',
#  'Phone': '',
#  'Email': '',
#  'Type of Service': '',
#  'Denomination': '',
#  'Service to be Held at': '',
#  'Address': '',
#  'Name of Clergy Preferred': '',
#  'Phone_2': '',
#  'Music': '',
#  'Requests': '',
#  'Readings': '',
#  'Casket': '',
#  'Urn': '',
#  'Vault': '',
#  'Visitation': '',
#  'Prayers': '',
#  'Limousines': '',
#  'Flowers': '',
#  'Death Certificates': '',
#  'Others': '',
#  'Pall Bearers 1': '',
#  'Pall Bearers 5': '',
#  'Paul Bearers 2': '',
#  'Paul Beares 6': '',
#  'Paul Bearers 3': '',
#  'Paul Bearers 7': '',
#  'Paul Bearers 4': '',
#  'Paul Bearers 8': '',
#  'Clothing  Jewellry': '',
#  'Burial  Cremation': '',
#  'Cemetery if required': '',
#  'Disposition of Cremated Remains': '',
#  'Plot if purchased': '',
#  'Vault_2': '',
#  'Marker': '',
# ...

# %%
fillpdfs.get_form_fields("Filled_Forms\Kris_Garcia - Instructions Concerning My Arrangements.pdf", sort=False, page_number=None)
# Out:
# {'Date': 'October 14, 2024',
#  'Kearney ColumbiaBowell Chapel': 'Yes',
#  'Kearney Vancouver Chapel': 'Yes',
#  'Kearney Cloverdale South Surrey': 'Yes',
#  'Kearney Burnaby Chapel': 'Yes',
#  'Name': 'Kris  Garcia',
#  'Phone': '778-926-8845',
#  'Email': 'kcgarcia_20@yahoo.ca',
#  'Type of Service': 'Full Funeral Service - Burial',
#  'Denomination': '',
#  'Service to be Held at': 'Kearney Burquitlam Funeral Home',
#  'Address': '102-200 Bernatchey St, Coquitlam, BC, V3K 0H8',
#  'Name of Clergy Preferred': '',
#  'Phone_2': '',
#  'Music': '',
#  'Requests': '',
#  'Readings': '',
#  'Casket': 'rental',
#  'Urn': 'aria',
#  'Vault': '',
#  'Visitation': '',
#  'Prayers': '',
#  'Limousines': '',
#  'Flowers': '',
#  'Death Certificates': '',
#  'Others': '',
#  'Pall Bearers 1': '',
#  'Pall Bearers 5': '',
#  'Paul Bearers 2': '',
#  'Paul Beares 6': '',
#  'Paul Bearers 3': '',
#  'Paul Bearers 7': '',
#  'Paul Bearers 4': '',
#  'Paul Bearers 8': '',
# ...

# %% [markdown]
# For the fourth PDF Forms\Pre-Arranged Funeral Service Agreement - New.pdf

# %%
fillpdfs.get_form_fields("Forms\Pre-Arranged Funeral Service Agreement - Full Funeral Service.pdf", sort=False, page_number=None)
# Out:
# {'Kearney Vancouver Chapel': '',
#  'Kearney ColumbiaBowell Chapel': '',
#  'Kearney Burquitlam Funeral Home': '',
#  'Kearney Burnaby Chapel': '',
#  'Kearney Cloverdale South Surrey': '',
#  'Purchaser': '',
#  'Phone Number': '',
#  'Address': '',
#  'Type of Service': '',
#  'A1': '',
#  'A2A': None,
#  'Pallbearers': '',
#  'A2B': None,
#  'Alternate Day Interment 1': '',
#  'A2C': None,
#  'Alternate Day Interment 2': '',
#  'A2D': '',
#  'A3': '',
#  'A4A': None,
#  'A4B': '',
#  'A4C': '',
#  'A5A': '',
#  'Embalming': '',
#  'A5B': '',
#  'Pacemaker Removal': '',
#  'A5C': '',
#  'Autopsy Care': '',
#  'A5D': '',
#  'Evening Prayers or Visitation': '',
#  'A6': '',
#  'Weekend or Statutory Holiday': '',
#  'A7': '',
#  'Reception Facilities': '',
#  'A8': '',
#  'Delivery of Cremated Remains': '',
#  'A9A': '',
#  'Transfer to Crematorium or Airport': '',
#  'A9B': '',
#  'Lead Vehicle': '',
#  'A9C': '',
#  'Service Vehicle': '',
#  'A9D': '',
#  'Funeral Coach': '',
# ...

# %%
fillpdfs.get_form_fields("Filled_Forms\Kris_Garcia - Pre-Arranged Funeral Service Agreement - Full Funeral Service.pdf", sort=False, page_number=None)
# Out:
# {'Kearney Vancouver Chapel': 'On',
#  'Kearney ColumbiaBowell Chapel': 'On',
#  'Kearney Burquitlam Funeral Home': 'On',
#  'Kearney Burnaby Chapel': 'On',
#  'Kearney Cloverdale South Surrey': 'On',
#  'Purchaser': 'Kris  Garcia',
#  'Phone Number': '778-926-8845',
#  'Address': '3 - 5410 Dundee St., Vancouver, BC, V5R 5Y6',
#  'Type of Service': 'Full Funeral Service - Burial',
#  'A1': '525.00',
#  'A2A': '2,755.00',
#  'Pallbearers': '',
#  'A2B': '',
#  'Alternate Day Interment 1': '',
#  'A2C': '',
#  'Alternate Day Interment 2': '',
#  'A2D': '',
#  'A3': '895.00',
#  'A4A': '365.00',
#  'A4B': '',
#  'A4C': '',
#  'A5A': '365.00',
#  'Embalming': '',
#  'A5B': '695.00',
#  'Pacemaker Removal': '',
#  'A5C': '',
#  'Autopsy Care': '',
#  'A5D': '',
#  'Evening Prayers or Visitation': '',
#  'A6': '695.00',
#  'Weekend or Statutory Holiday': '',
#  'A7': '',
#  'Reception Facilities': '',
#  'A8': '',
#  'Delivery of Cremated Remains': '',
#  'A9A': '',
# ...
